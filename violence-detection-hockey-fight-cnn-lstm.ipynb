# %% [markdown]
# # Violence Detection using CNN + LSTM neural netowrk

# %% [markdown]
# ## Introduction

# %% [markdown]
# Today, the amount of public violence has increased dramatically. As much in high schools as in the street. This has resulted in the ubiquitous use of surveillance cameras. This has helped the authorities to identify these events and take the necessary measures. But almost all systems today require the human-inspection of these videos to identify such events, which is virtually inefficient. It is therefore necessary to have such a practical system that can automatically monitor and identify the surveillance videos.
# The development of various deep learning techniques, thanks to the availability of large data sets and computational resources, has resulted in a historic change in the community of computer vision. Various techniques have been developed to address problems such as object detection, recognition, tracking, action recognition, legend generation, etc. However, despite recent developments in deep learning, very few techniques based on deep learning have been proposed to address the problem of detecting violence from videos.

# %% [markdown]
# ## Flowchart

# %% [markdown]
# The method consists of extracting a set of frames belonging to the video, sending them to a pretrained network called VGG16, obtaining the output of one of its final layers and from these outputs train another network architecture with a type of special neurons called LSTM. These neurons have memory and are able to analyze the temporal information of the video, if at any time they detect violence, it will be classified as a violent video.

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import cv2
import os
import numpy as np
import keras
import matplotlib.pyplot as plt
# import download
from random import shuffle
from tensorflow.keras.applications import VGG16
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Activation
import sys
import h5py

# %%
keras.__version__
# Out:
# '2.4.3'

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# We will use the function ```print_progress``` to print the amount of videos processed the datasets

# %%
def print_progress(count, max_count):
    # Percentage completion.
    pct_complete = count / max_count

    # Status-message. Note the \r which means the line should
    # overwrite itself.
    msg = "\r- Progress: {0:.1%}".format(pct_complete)

    # Print it.
    sys.stdout.write(msg)
    sys.stdout.flush()

# %% [markdown]
# ## Load Data
#
# Firstly, we define the directory to place the video dataset

# %%
in_dir = "../input/hockey-fight-vidoes/data"

# %% [markdown]
# Copy some of the data-dimensions for convenience.

# %%
# Frame size  
img_size = 224

img_size_touple = (img_size, img_size)

# Number of channels (RGB)
num_channels = 3

# Flat frame size
img_size_flat = img_size * img_size * num_channels

# Number of classes for classification (Violence-No Violence)
num_classes = 2

# Number of files to train
_num_files_train = 1

# Number of frames per video
_images_per_file = 20

# Number of frames per training set
_num_images_train = _num_files_train * _images_per_file

# Video extension
video_exts = ".avi"

# %% [markdown]
# ### Helper-function for getting video frames
# Function used to get 20 frames from a video file and convert the frame to a suitable format for the neural net.

# %%
def get_frames(current_dir, file_name):
    
    in_file = os.path.join(current_dir, file_name)
    
    images = []
    
    vidcap = cv2.VideoCapture(in_file)
    
    success,image = vidcap.read()
        
    count = 0

    while count<_images_per_file:
                
        RGB_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
        res = cv2.resize(RGB_img, dsize=(img_size, img_size),
                                 interpolation=cv2.INTER_CUBIC)
    
        images.append(res)
    
        success,image = vidcap.read()
    
        count += 1
        
    resul = np.array(images)
    
    resul = (resul / 255.).astype(np.float16)
        
    return resul

# %% [markdown]
# ### Helper function to get the names of the data downloaded and label it

# %%
def label_video_names(in_dir):
    
    # list containing video names
    names = []
    # list containin video labels [1, 0] if it has violence and [0, 1] if not
    labels = []
    
    
    for current_dir, dir_names,file_names in os.walk(in_dir):
        
        for file_name in file_names:
            
            if file_name[0:2] == 'fi':
                labels.append([1,0])
                names.append(file_name)
            elif file_name[0:2] == 'no':
                labels.append([0,1])
                names.append(file_name)
                     
            
    c = list(zip(names,labels))
    # Suffle the data (names and labels)
    shuffle(c)
    
    names, labels = zip(*c)
            
    return names, labels

# %% [markdown]
# ### Plot a video frame to see if data is correct

# %%
# First get the names and labels of the whole videos
names, labels = label_video_names(in_dir)

# %% [markdown]
# Then we are going to load 20 frames of one video, for example

# %%
names[12]
# Out:
# 'no285_xvid.avi'

# %% [markdown]
# The video has violence, look at the name of the video, starts with 'fi'

# %%
frames = get_frames(in_dir, names[12])

# %% [markdown]
# Convert back the frames to uint8 pixel format to plot the frame

# %%
visible_frame = (frames*255).astype('uint8')

# %%
plt.imshow(visible_frame[3])

# %%
plt.imshow(visible_frame[15])

# %% [markdown]
# ## Pre-Trained Model: VGG16

# %% [markdown]
# The following creates an instance of the pre-trained VGG16 model using the Keras API. This automatically downloads the required files if you don't have them already.
#
# The VGG16 model contains a convolutional part and a fully-connected (or dense) part which is used for classification. If include_top=True then the whole VGG16 model is downloaded which is about 528 MB. If include_top=False then only the convolutional part of the VGG16 model is downloaded which is just 57 MB.

# %%
image_model = VGG16(include_top=True, weights='imagenet')

# %% [markdown]
# Let's see the model summary

# %%
image_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We can observe the shape of the tensors expected as input by the pre-trained VGG16 model. In this case it is images of shape 224 x 224 x 3. Note that we have defined the frame size as 224x224x3. The video frame will be the input of the VGG16 net.

# %% [markdown]
# ### VGG16 model flowchart

# %% [markdown]
# The following chart shows how the data flows when using the VGG16 model for Transfer Learning. First we input and process 20 video frames in batch with the VGG16 model. Just prior to the final classification layer of the VGG16 model, we save the so-called Transfer Values to a cache-file.
#
# The reason for using a cache-file is that it takes a long time to process an image with the VGG16 model. If each image is processed more than once then we can save a lot of time by caching the transfer-values.
#
# When all the videos have been processed through the VGG16 model and the resulting transfer-values saved to a cache file, then we can use those transfer-values as the input to LSTM neural network. We will then train the second neural network using the classes from the violence dataset (Violence, No-Violence), so the network learns how to classify images based on the transfer-values from the VGG16 model.

# %%
# We will use the output of the layer prior to the final
# classification-layer which is named fc2. This is a fully-connected (or dense) layer.
transfer_layer = image_model.get_layer('fc2')

image_model_transfer = Model(inputs=image_model.input,
                             outputs=transfer_layer.output)

transfer_values_size = K.int_shape(transfer_layer.output)[1]


print("The input of the VGG16 net have dimensions:",K.int_shape(image_model.input)[1:3])

print("The output of the selecter layer of VGG16 net have dimensions: ", transfer_values_size)
# Out:
# The input of the VGG16 net have dimensions: (224, 224)
# The output of the selecter layer of VGG16 net have dimensions:  4096

# %% [markdown]
# ### Function to process 20 video frames through VGG16 and get transfer values

# %%
def get_transfer_values(current_dir, file_name):
    
    # Pre-allocate input-batch-array for images.
    shape = (_images_per_file,) + img_size_touple + (3,)
    
    image_batch = np.zeros(shape=shape, dtype=np.float16)
    
    image_batch = get_frames(current_dir, file_name)
      
    # Pre-allocate output-array for transfer-values.
    # Note that we use 16-bit floating-points to save memory.
    shape = (_images_per_file, transfer_values_size)
    transfer_values = np.zeros(shape=shape, dtype=np.float16)

    transfer_values = \
            image_model_transfer.predict(image_batch)
            
    return transfer_values

# %% [markdown]
# ### Generator that process one video through VGG16 each function call

# %%
def proces_transfer(vid_names, in_dir, labels):
    
    count = 0
    
    tam = len(vid_names)
    
    # Pre-allocate input-batch-array for images.
    shape = (_images_per_file,) + img_size_touple + (3,)
    
    while count<tam:
        
        video_name = vid_names[count]
        
        image_batch = np.zeros(shape=shape, dtype=np.float16)
    
        image_batch = get_frames(in_dir, video_name)
        
         # Note that we use 16-bit floating-points to save memory.
        shape = (_images_per_file, transfer_values_size)
        transfer_values = np.zeros(shape=shape, dtype=np.float16)
        
        transfer_values = \
            image_model_transfer.predict(image_batch)
         
        labels1 = labels[count]
        
        aux = np.ones([20,2])
        
        labelss = labels1*aux
        
        yield transfer_values, labelss
        
        count+=1

# %% [markdown]
# ### Functions to save transfer values from VGG16 to later use
# We are going to define functions to get the transfer values from VGG16 with defined number of files. Then save the transfer values files used from training in one file and the ones uses for testing in another one.

# %%
def make_files(n_files):
    
    gen = proces_transfer(names_training, in_dir, labels_training)

    numer = 1

    # Read the first chunk to get the column dtypes
    chunk = next(gen)

    row_count = chunk[0].shape[0]
    row_count2 = chunk[1].shape[0]
    
    with h5py.File('prueba.h5', 'w') as f:
    
        # Initialize a resizable dataset to hold the output
        maxshape = (None,) + chunk[0].shape[1:]
        maxshape2 = (None,) + chunk[1].shape[1:]
    
    
        dset = f.create_dataset('data', shape=chunk[0].shape, maxshape=maxshape,
                                chunks=chunk[0].shape, dtype=chunk[0].dtype)
    
        dset2 = f.create_dataset('labels', shape=chunk[1].shape, maxshape=maxshape2,
                                 chunks=chunk[1].shape, dtype=chunk[1].dtype)
    
         # Write the first chunk of rows
        dset[:] = chunk[0]
        dset2[:] = chunk[1]

        for chunk in gen:
            
            if numer == n_files:
            
                break

            # Resize the dataset to accommodate the next chunk of rows
            dset.resize(row_count + chunk[0].shape[0], axis=0)
            dset2.resize(row_count2 + chunk[1].shape[0], axis=0)

            # Write the next chunk
            dset[row_count:] = chunk[0]
            dset2[row_count:] = chunk[1]

            # Increment the row count
            row_count += chunk[0].shape[0]
            row_count2 += chunk[1].shape[0]
            
            print_progress(numer, n_files)
        
            numer += 1

# %%
def make_files_test(n_files):
    
    gen = proces_transfer(names_test, in_dir, labels_test)

    numer = 1

    # Read the first chunk to get the column dtypes
    chunk = next(gen)

    row_count = chunk[0].shape[0]
    row_count2 = chunk[1].shape[0]
    
    with h5py.File('pruebavalidation.h5', 'w') as f:
    
        # Initialize a resizable dataset to hold the output
        maxshape = (None,) + chunk[0].shape[1:]
        maxshape2 = (None,) + chunk[1].shape[1:]
    
    
        dset = f.create_dataset('data', shape=chunk[0].shape, maxshape=maxshape,
                                chunks=chunk[0].shape, dtype=chunk[0].dtype)
    
        dset2 = f.create_dataset('labels', shape=chunk[1].shape, maxshape=maxshape2,
                                 chunks=chunk[1].shape, dtype=chunk[1].dtype)
    
         # Write the first chunk of rows
        dset[:] = chunk[0]
        dset2[:] = chunk[1]

        for chunk in gen:
            
            if numer == n_files:
            
                break

            # Resize the dataset to accommodate the next chunk of rows
            dset.resize(row_count + chunk[0].shape[0], axis=0)
            dset2.resize(row_count2 + chunk[1].shape[0], axis=0)

            # Write the next chunk
            dset[row_count:] = chunk[0]
            dset2[row_count:] = chunk[1]

            # Increment the row count
            row_count += chunk[0].shape[0]
            row_count2 += chunk[1].shape[0]
            
            print_progress(numer, n_files)
        
            numer += 1

# %% [markdown]
# ### Split the dataset into training set and test set
# We are going to split the dataset into training set and testing. The training set is used to train the model and the test set to check the model accuracy.

# %%
training_set = int(len(names)*0.8)
test_set = int(len(names)*0.2)

names_training = names[0:training_set]
names_test = names[training_set:]

labels_training = labels[0:training_set]
labels_test = labels[training_set:]

# %% [markdown]
# Then we are going to process all video frames through VGG16 and save the transfer values.

# %%
make_files(training_set)
# Out:
# - Progress: 99.9%

# %%
make_files_test(test_set)
# Out:
# - Progress: 99.5%

# %% [markdown]
# ### Load the cached transfer values into memory
# We have already saved all the videos transfer values into disk. But we have to load those transfer values into memory in order to train the LSTM net. One question would be: why not process transfer values and load them into RAM memory? Yes is a more eficient way to train the second net. But if you have to train the LSTM in different ways in order to see which way gets the best accuracy, if you didn't save the transfer values into disk you would have to process the whole videos each training. It's very time consuming processing the videos through VGG16 net.

# %% [markdown]
# In order to load the saved transfer values into RAM memory we are going to use this two functions:

# %%
def process_alldata_training():
    
    joint_transfer=[]
    frames_num=20
    count = 0
    
    with h5py.File('prueba.h5', 'r') as f:
            
        X_batch = f['data'][:]
        y_batch = f['labels'][:]

    for i in range(int(len(X_batch)/frames_num)):
        inc = count+frames_num
        joint_transfer.append([X_batch[count:inc],y_batch[count]])
        count =inc
        
    data =[]
    target=[]
    
    for i in joint_transfer:
        data.append(i[0])
        target.append(np.array(i[1]))
        
    return data, target

# %%
def process_alldata_test():
    
    joint_transfer=[]
    frames_num=20
    count = 0
    
    with h5py.File('pruebavalidation.h5', 'r') as f:
            
        X_batch = f['data'][:]
        y_batch = f['labels'][:]

    for i in range(int(len(X_batch)/frames_num)):
        inc = count+frames_num
        joint_transfer.append([X_batch[count:inc],y_batch[count]])
        count =inc
        
    data =[]
    target=[]
    
    for i in joint_transfer:
        data.append(i[0])
        target.append(np.array(i[1]))
        
    return data, target

# %%
data, target = process_alldata_training()

# %%
data_test, target_test = process_alldata_test()

# %% [markdown]
# ##Recurrent Neural Network

# %% [markdown]
# The basic building block in a Recurrent Neural Network (RNN) is a Recurrent Unit (RU). There are many different variants of recurrent units such as the rather clunky LSTM (Long-Short-Term-Memory) and the somewhat simpler GRU (Gated Recurrent Unit) which we will use in this tutorial. Experiments in the literature suggest that the LSTM and GRU have roughly similar performance. Even simpler variants also exist and the literature suggests that they may perform even better than both LSTM and GRU, but they are not implemented in Keras which we will use in this tutorial.
#
# A recurrent neuron has an internal state that is being updated every time the unit receives a new input. This internal state serves as a kind of memory. However, it is not a traditional kind of computer memory which stores bits that are either on or off. Instead the recurrent unit stores floating-point values in its memory-state, which are read and written using matrix-operations so the operations are all differentiable. This means the memory-state can store arbitrary floating-point values (although typically limited between -1.0 and 1.0) and the network can be trained like a normal neural network using Gradient Descent.

# %% [markdown]
# ### Define LSTM architecture

# %% [markdown]
# When defining the LSTM architecture we have to take into account the dimensions of the transfer values. From each frame the VGG16 network obtains as output a vector of 4096 transfer values. From each video we are processing 20 frames so we will have 20 x 4096 values per video. The classification must be done taking into account the 20 frames of the video. If any of them detects violence, the video will be classified as violent.

# %% [markdown]
# The first input dimension of LSTM neurons is the temporal dimension, in our case it is 20. The second is the size of the features vector (transfer values).

# %%
chunk_size = 4096
n_chunks = 20
rnn_size = 512

model = Sequential()
model.add(LSTM(rnn_size, input_shape=(n_chunks, chunk_size)))
model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dense(50))
model.add(Activation('sigmoid'))
model.add(Dense(2))
model.add(Activation('softmax'))
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# ## Model training

# %%
epoch = 200
batchS = 500

history = model.fit(np.array(data[0:720]), np.array(target[0:720]), epochs=epoch,
                    validation_data=(np.array(data[720:]), np.array(target[720:])), 
                    batch_size=batchS, verbose=2)
# Out:
# Epoch 1/200
# 2/2 - 2s - loss: 0.3429 - accuracy: 0.4653 - val_loss: 0.3254 - val_accuracy: 0.4500
# Epoch 2/200
# 2/2 - 0s - loss: 0.2974 - accuracy: 0.4819 - val_loss: 0.2604 - val_accuracy: 0.5500
# Epoch 3/200
# 2/2 - 0s - loss: 0.2694 - accuracy: 0.5042 - val_loss: 0.2487 - val_accuracy: 0.4625
# Epoch 4/200
# 2/2 - 0s - loss: 0.2507 - accuracy: 0.5278 - val_loss: 0.2704 - val_accuracy: 0.4500
# Epoch 5/200
# 2/2 - 0s - loss: 0.2596 - accuracy: 0.4958 - val_loss: 0.2543 - val_accuracy: 0.4500
# Epoch 6/200
# 2/2 - 0s - loss: 0.2484 - accuracy: 0.6083 - val_loss: 0.2413 - val_accuracy: 0.5500
# Epoch 7/200
# 2/2 - 0s - loss: 0.2446 - accuracy: 0.5042 - val_loss: 0.2405 - val_accuracy: 0.5500
# Epoch 8/200
# 2/2 - 0s - loss: 0.2444 - accuracy: 0.5042 - val_loss: 0.2424 - val_accuracy: 0.5500
# Epoch 9/200
# 2/2 - 0s - loss: 0.2433 - accuracy: 0.5486 - val_loss: 0.2377 - val_accuracy: 0.4500
# Epoch 10/200
# 2/2 - 0s - loss: 0.2369 - accuracy: 0.4958 - val_loss: 0.2360 - val_accuracy: 0.4625
# Epoch 11/200
# 2/2 - 0s - loss: 0.2312 - accuracy: 0.6000 - val_loss: 0.2249 - val_accuracy: 0.8000
# Epoch 12/200
# 2/2 - 0s - loss: 0.2237 - accuracy: 0.8097 - val_loss: 0.2149 - val_accuracy: 0.8625
# Epoch 13/200
# 2/2 - 0s - loss: 0.2113 - accuracy: 0.8792 - val_loss: 0.1979 - val_accuracy: 0.9375
# Epoch 14/200
# 2/2 - 0s - loss: 0.1954 - accuracy: 0.8986 - val_loss: 0.1819 - val_accuracy: 0.8875
# Epoch 15/200
# 2/2 - 0s - loss: 0.1801 - accuracy: 0.8861 - val_loss: 0.1759 - val_accuracy: 0.8500
# Epoch 16/200
# 2/2 - 0s - loss: 0.1632 - accuracy: 0.8764 - val_loss: 0.1412 - val_accuracy: 0.8875
# Epoch 17/200
# 2/2 - 0s - loss: 0.1409 - accuracy: 0.8792 - val_loss: 0.1318 - val_accuracy: 0.8875
# Epoch 18/200
# 2/2 - 0s - loss: 0.1219 - accuracy: 0.9028 - val_loss: 0.1210 - val_accuracy: 0.8375
# Epoch 19/200
# 2/2 - 0s - loss: 0.1176 - accuracy: 0.8736 - val_loss: 0.1459 - val_accuracy: 0.7750
# Epoch 20/200
# 2/2 - 0s - loss: 0.1202 - accuracy: 0.8542 - val_loss: 0.0892 - val_accuracy: 0.9125
# Epoch 21/200
# 2/2 - 0s - loss: 0.0966 - accuracy: 0.8833 - val_loss: 0.0936 - val_accuracy: 0.9000
# Epoch 22/200
# 2/2 - 0s - loss: 0.0952 - accuracy: 0.8986 - val_loss: 0.0802 - val_accuracy: 0.9125
# Epoch 23/200
# 2/2 - 0s - loss: 0.0926 - accuracy: 0.8875 - val_loss: 0.0721 - val_accuracy: 0.9250
# Epoch 24/200
# 2/2 - 0s - loss: 0.0868 - accuracy: 0.8986 - val_loss: 0.0724 - val_accuracy: 0.9250
# Epoch 25/200
# 2/2 - 0s - loss: 0.0794 - accuracy: 0.9069 - val_loss: 0.0730 - val_accuracy: 0.9125
# Epoch 26/200
# 2/2 - 0s - loss: 0.0873 - accuracy: 0.8889 - val_loss: 0.0741 - val_accuracy: 0.9125
# Epoch 27/200
# 2/2 - 0s - loss: 0.0786 - accuracy: 0.9028 - val_loss: 0.0645 - val_accuracy: 0.9250
# Epoch 28/200
# 2/2 - 0s - loss: 0.0763 - accuracy: 0.9083 - val_loss: 0.0626 - val_accuracy: 0.9250
# Epoch 29/200
# 2/2 - 0s - loss: 0.0748 - accuracy: 0.9097 - val_loss: 0.0668 - val_accuracy: 0.9125
# Epoch 30/200
# 2/2 - 0s - loss: 0.0739 - accuracy: 0.9111 - val_loss: 0.0600 - val_accuracy: 0.9375
# Epoch 31/200
# 2/2 - 0s - loss: 0.0765 - accuracy: 0.9083 - val_loss: 0.0616 - val_accuracy: 0.9250
# Epoch 32/200
# 2/2 - 0s - loss: 0.0715 - accuracy: 0.9181 - val_loss: 0.0788 - val_accuracy: 0.9125
# Epoch 33/200
# 2/2 - 0s - loss: 0.0772 - accuracy: 0.9042 - val_loss: 0.0591 - val_accuracy: 0.9250
# Epoch 34/200
# 2/2 - 0s - loss: 0.0705 - accuracy: 0.9139 - val_loss: 0.0663 - val_accuracy: 0.9375
# Epoch 35/200
# 2/2 - 0s - loss: 0.0701 - accuracy: 0.9181 - val_loss: 0.0600 - val_accuracy: 0.9250
# Epoch 36/200
# 2/2 - 0s - loss: 0.0683 - accuracy: 0.9222 - val_loss: 0.0578 - val_accuracy: 0.9250
# Epoch 37/200
# 2/2 - 0s - loss: 0.0686 - accuracy: 0.9181 - val_loss: 0.0585 - val_accuracy: 0.9250
# Epoch 38/200
# 2/2 - 0s - loss: 0.0669 - accuracy: 0.9222 - val_loss: 0.0581 - val_accuracy: 0.9250
# Epoch 39/200
# 2/2 - 0s - loss: 0.0660 - accuracy: 0.9250 - val_loss: 0.0626 - val_accuracy: 0.9375
# Epoch 40/200
# 2/2 - 0s - loss: 0.0653 - accuracy: 0.9264 - val_loss: 0.0576 - val_accuracy: 0.9250
# Epoch 41/200
# 2/2 - 0s - loss: 0.0646 - accuracy: 0.9250 - val_loss: 0.0660 - val_accuracy: 0.9375
# Epoch 42/200
# 2/2 - 0s - loss: 0.0653 - accuracy: 0.9236 - val_loss: 0.0529 - val_accuracy: 0.9375
# Epoch 43/200
# 2/2 - 0s - loss: 0.0695 - accuracy: 0.9097 - val_loss: 0.0693 - val_accuracy: 0.9375
# Epoch 44/200
# 2/2 - 0s - loss: 0.0661 - accuracy: 0.9236 - val_loss: 0.0523 - val_accuracy: 0.9250
# Epoch 45/200
# 2/2 - 0s - loss: 0.0660 - accuracy: 0.9194 - val_loss: 0.0604 - val_accuracy: 0.9375
# Epoch 46/200
# 2/2 - 0s - loss: 0.0639 - accuracy: 0.9264 - val_loss: 0.0549 - val_accuracy: 0.9375
# Epoch 47/200
# 2/2 - 0s - loss: 0.0617 - accuracy: 0.9278 - val_loss: 0.0505 - val_accuracy: 0.9250
# Epoch 48/200
# 2/2 - 0s - loss: 0.0617 - accuracy: 0.9306 - val_loss: 0.0913 - val_accuracy: 0.8625
# Epoch 49/200
# 2/2 - 0s - loss: 0.0718 - accuracy: 0.9083 - val_loss: 0.0487 - val_accuracy: 0.9375
# Epoch 50/200
# 2/2 - 0s - loss: 0.0616 - accuracy: 0.9264 - val_loss: 0.0974 - val_accuracy: 0.8625
# Epoch 51/200
# 2/2 - 0s - loss: 0.0694 - accuracy: 0.9097 - val_loss: 0.0475 - val_accuracy: 0.9500
# Epoch 52/200
# 2/2 - 0s - loss: 0.0665 - accuracy: 0.9167 - val_loss: 0.0895 - val_accuracy: 0.8625
# Epoch 53/200
# 2/2 - 0s - loss: 0.0683 - accuracy: 0.9153 - val_loss: 0.0517 - val_accuracy: 0.9375
# Epoch 54/200
# 2/2 - 0s - loss: 0.0575 - accuracy: 0.9361 - val_loss: 0.0468 - val_accuracy: 0.9250
# Epoch 55/200
# 2/2 - 0s - loss: 0.0591 - accuracy: 0.9292 - val_loss: 0.0703 - val_accuracy: 0.9250
# Epoch 56/200
# 2/2 - 0s - loss: 0.0594 - accuracy: 0.9361 - val_loss: 0.0480 - val_accuracy: 0.9375
# Epoch 57/200
# 2/2 - 0s - loss: 0.0578 - accuracy: 0.9347 - val_loss: 0.0560 - val_accuracy: 0.9375
# Epoch 58/200
# 2/2 - 0s - loss: 0.0584 - accuracy: 0.9319 - val_loss: 0.0481 - val_accuracy: 0.9375
# Epoch 59/200
# 2/2 - 0s - loss: 0.0563 - accuracy: 0.9347 - val_loss: 0.0445 - val_accuracy: 0.9375
# Epoch 60/200
# 2/2 - 0s - loss: 0.0557 - accuracy: 0.9333 - val_loss: 0.0991 - val_accuracy: 0.8625
# Epoch 61/200
# 2/2 - 0s - loss: 0.0669 - accuracy: 0.9167 - val_loss: 0.0422 - val_accuracy: 0.9500
# Epoch 62/200
# 2/2 - 0s - loss: 0.0638 - accuracy: 0.9306 - val_loss: 0.0815 - val_accuracy: 0.8875
# Epoch 63/200
# 2/2 - 0s - loss: 0.0606 - accuracy: 0.9292 - val_loss: 0.0408 - val_accuracy: 0.9500
# Epoch 64/200
# 2/2 - 0s - loss: 0.0600 - accuracy: 0.9250 - val_loss: 0.0534 - val_accuracy: 0.9375
# Epoch 65/200
# 2/2 - 0s - loss: 0.0542 - accuracy: 0.9417 - val_loss: 0.0599 - val_accuracy: 0.9250
# Epoch 66/200
# 2/2 - 0s - loss: 0.0541 - accuracy: 0.9361 - val_loss: 0.0406 - val_accuracy: 0.9500
# Epoch 67/200
# 2/2 - 0s - loss: 0.0552 - accuracy: 0.9333 - val_loss: 0.0783 - val_accuracy: 0.9000
# Epoch 68/200
# 2/2 - 0s - loss: 0.0580 - accuracy: 0.9333 - val_loss: 0.0388 - val_accuracy: 0.9500
# Epoch 69/200
# 2/2 - 0s - loss: 0.0572 - accuracy: 0.9347 - val_loss: 0.0660 - val_accuracy: 0.9250
# Epoch 70/200
# 2/2 - 0s - loss: 0.0548 - accuracy: 0.9403 - val_loss: 0.0446 - val_accuracy: 0.9375
# Epoch 71/200
# 2/2 - 0s - loss: 0.0533 - accuracy: 0.9361 - val_loss: 0.0486 - val_accuracy: 0.9375
# Epoch 72/200
# 2/2 - 0s - loss: 0.0513 - accuracy: 0.9431 - val_loss: 0.0643 - val_accuracy: 0.9250
# Epoch 73/200
# 2/2 - 0s - loss: 0.0541 - accuracy: 0.9403 - val_loss: 0.0438 - val_accuracy: 0.9375
# Epoch 74/200
# 2/2 - 0s - loss: 0.0526 - accuracy: 0.9389 - val_loss: 0.0436 - val_accuracy: 0.9375
# Epoch 75/200
# 2/2 - 0s - loss: 0.0517 - accuracy: 0.9389 - val_loss: 0.0554 - val_accuracy: 0.9250
# Epoch 76/200
# 2/2 - 0s - loss: 0.0513 - accuracy: 0.9417 - val_loss: 0.0440 - val_accuracy: 0.9375
# Epoch 77/200
# 2/2 - 0s - loss: 0.0504 - accuracy: 0.9431 - val_loss: 0.0498 - val_accuracy: 0.9250
# Epoch 78/200
# 2/2 - 0s - loss: 0.0494 - accuracy: 0.9458 - val_loss: 0.0609 - val_accuracy: 0.9250
# Epoch 79/200
# 2/2 - 0s - loss: 0.0503 - accuracy: 0.9444 - val_loss: 0.0366 - val_accuracy: 0.9625
# Epoch 80/200
# 2/2 - 0s - loss: 0.0501 - accuracy: 0.9444 - val_loss: 0.0797 - val_accuracy: 0.9000
# Epoch 81/200
# 2/2 - 0s - loss: 0.0559 - accuracy: 0.9403 - val_loss: 0.0341 - val_accuracy: 0.9625
# Epoch 82/200
# 2/2 - 0s - loss: 0.0545 - accuracy: 0.9361 - val_loss: 0.0517 - val_accuracy: 0.9250
# Epoch 83/200
# 2/2 - 0s - loss: 0.0476 - accuracy: 0.9472 - val_loss: 0.0331 - val_accuracy: 0.9750
# Epoch 84/200
# 2/2 - 0s - loss: 0.0539 - accuracy: 0.9333 - val_loss: 0.0590 - val_accuracy: 0.9250
# Epoch 85/200
# 2/2 - 0s - loss: 0.0479 - accuracy: 0.9472 - val_loss: 0.0324 - val_accuracy: 0.9750
# Epoch 86/200
# 2/2 - 0s - loss: 0.0518 - accuracy: 0.9333 - val_loss: 0.0716 - val_accuracy: 0.9125
# Epoch 87/200
# 2/2 - 0s - loss: 0.0506 - accuracy: 0.9417 - val_loss: 0.0317 - val_accuracy: 0.9750
# Epoch 88/200
# 2/2 - 0s - loss: 0.0518 - accuracy: 0.9361 - val_loss: 0.0578 - val_accuracy: 0.9375
# Epoch 89/200
# 2/2 - 0s - loss: 0.0475 - accuracy: 0.9472 - val_loss: 0.0309 - val_accuracy: 0.9750
# Epoch 90/200
# 2/2 - 0s - loss: 0.0520 - accuracy: 0.9361 - val_loss: 0.0501 - val_accuracy: 0.9375
# Epoch 91/200
# 2/2 - 0s - loss: 0.0479 - accuracy: 0.9472 - val_loss: 0.0430 - val_accuracy: 0.9250
# Epoch 92/200
# 2/2 - 0s - loss: 0.0457 - accuracy: 0.9500 - val_loss: 0.0464 - val_accuracy: 0.9375
# Epoch 93/200
# 2/2 - 0s - loss: 0.0472 - accuracy: 0.9486 - val_loss: 0.0408 - val_accuracy: 0.9250
# Epoch 94/200
# 2/2 - 0s - loss: 0.0487 - accuracy: 0.9431 - val_loss: 0.0308 - val_accuracy: 0.9750
# Epoch 95/200
# 2/2 - 0s - loss: 0.0548 - accuracy: 0.9319 - val_loss: 0.1202 - val_accuracy: 0.8125
# Epoch 96/200
# 2/2 - 0s - loss: 0.0645 - accuracy: 0.9222 - val_loss: 0.0292 - val_accuracy: 0.9750
# Epoch 97/200
# 2/2 - 0s - loss: 0.0522 - accuracy: 0.9389 - val_loss: 0.0474 - val_accuracy: 0.9375
# Epoch 98/200
# 2/2 - 0s - loss: 0.0452 - accuracy: 0.9500 - val_loss: 0.0285 - val_accuracy: 0.9750
# Epoch 99/200
# 2/2 - 0s - loss: 0.0498 - accuracy: 0.9403 - val_loss: 0.0661 - val_accuracy: 0.9125
# Epoch 100/200
# 2/2 - 0s - loss: 0.0499 - accuracy: 0.9444 - val_loss: 0.0304 - val_accuracy: 0.9625
# Epoch 101/200
# 2/2 - 0s - loss: 0.0450 - accuracy: 0.9542 - val_loss: 0.0639 - val_accuracy: 0.9125
# Epoch 102/200
# 2/2 - 0s - loss: 0.0481 - accuracy: 0.9500 - val_loss: 0.0274 - val_accuracy: 0.9750
# Epoch 103/200
# 2/2 - 0s - loss: 0.0488 - accuracy: 0.9458 - val_loss: 0.0676 - val_accuracy: 0.9125
# Epoch 104/200
# 2/2 - 0s - loss: 0.0512 - accuracy: 0.9431 - val_loss: 0.0270 - val_accuracy: 0.9750
# Epoch 105/200
# 2/2 - 0s - loss: 0.0475 - accuracy: 0.9486 - val_loss: 0.0608 - val_accuracy: 0.9250
# Epoch 106/200
# 2/2 - 0s - loss: 0.0447 - accuracy: 0.9514 - val_loss: 0.0310 - val_accuracy: 0.9750
# Epoch 107/200
# 2/2 - 0s - loss: 0.0562 - accuracy: 0.9278 - val_loss: 0.1148 - val_accuracy: 0.8125
# Epoch 108/200
# 2/2 - 0s - loss: 0.0628 - accuracy: 0.9236 - val_loss: 0.0386 - val_accuracy: 0.9375
# Epoch 109/200
# 2/2 - 0s - loss: 0.0710 - accuracy: 0.9111 - val_loss: 0.1205 - val_accuracy: 0.8000
# Epoch 110/200
# 2/2 - 0s - loss: 0.0589 - accuracy: 0.9236 - val_loss: 0.0554 - val_accuracy: 0.9250
# Epoch 111/200
# 2/2 - 0s - loss: 0.0768 - accuracy: 0.9097 - val_loss: 0.1668 - val_accuracy: 0.7875
# Epoch 112/200
# 2/2 - 0s - loss: 0.0801 - accuracy: 0.8944 - val_loss: 0.0370 - val_accuracy: 0.9500
# Epoch 113/200
# 2/2 - 0s - loss: 0.0696 - accuracy: 0.9097 - val_loss: 0.0472 - val_accuracy: 0.9375
# Epoch 114/200
# 2/2 - 0s - loss: 0.0551 - accuracy: 0.9347 - val_loss: 0.0299 - val_accuracy: 0.9500
# Epoch 115/200
# 2/2 - 0s - loss: 0.0559 - accuracy: 0.9361 - val_loss: 0.0271 - val_accuracy: 0.9750
# Epoch 116/200
# 2/2 - 0s - loss: 0.0484 - accuracy: 0.9472 - val_loss: 0.1081 - val_accuracy: 0.8375
# Epoch 117/200
# 2/2 - 0s - loss: 0.0621 - accuracy: 0.9250 - val_loss: 0.0381 - val_accuracy: 0.9500
# Epoch 118/200
# 2/2 - 0s - loss: 0.0698 - accuracy: 0.9097 - val_loss: 0.0414 - val_accuracy: 0.9500
# Epoch 119/200
# 2/2 - 0s - loss: 0.0460 - accuracy: 0.9500 - val_loss: 0.0762 - val_accuracy: 0.9000
# Epoch 120/200
# 2/2 - 0s - loss: 0.0517 - accuracy: 0.9403 - val_loss: 0.0272 - val_accuracy: 0.9750
# Epoch 121/200
# 2/2 - 0s - loss: 0.0493 - accuracy: 0.9458 - val_loss: 0.0397 - val_accuracy: 0.9500
# Epoch 122/200
# 2/2 - 0s - loss: 0.0466 - accuracy: 0.9458 - val_loss: 0.0482 - val_accuracy: 0.9375
# Epoch 123/200
# 2/2 - 0s - loss: 0.0458 - accuracy: 0.9500 - val_loss: 0.0269 - val_accuracy: 0.9750
# Epoch 124/200
# 2/2 - 0s - loss: 0.0475 - accuracy: 0.9458 - val_loss: 0.0345 - val_accuracy: 0.9500
# Epoch 125/200
# 2/2 - 0s - loss: 0.0444 - accuracy: 0.9500 - val_loss: 0.0382 - val_accuracy: 0.9500
# Epoch 126/200
# 2/2 - 0s - loss: 0.0441 - accuracy: 0.9486 - val_loss: 0.0311 - val_accuracy: 0.9625
# Epoch 127/200
# 2/2 - 0s - loss: 0.0437 - accuracy: 0.9514 - val_loss: 0.0318 - val_accuracy: 0.9625
# Epoch 128/200
# 2/2 - 0s - loss: 0.0433 - accuracy: 0.9514 - val_loss: 0.0308 - val_accuracy: 0.9625
# Epoch 129/200
# 2/2 - 0s - loss: 0.0430 - accuracy: 0.9514 - val_loss: 0.0294 - val_accuracy: 0.9625
# Epoch 130/200
# 2/2 - 0s - loss: 0.0427 - accuracy: 0.9528 - val_loss: 0.0328 - val_accuracy: 0.9625
# Epoch 131/200
# 2/2 - 0s - loss: 0.0427 - accuracy: 0.9528 - val_loss: 0.0295 - val_accuracy: 0.9625
# Epoch 132/200
# 2/2 - 0s - loss: 0.0435 - accuracy: 0.9542 - val_loss: 0.0342 - val_accuracy: 0.9625
# Epoch 133/200
# 2/2 - 0s - loss: 0.0425 - accuracy: 0.9528 - val_loss: 0.0420 - val_accuracy: 0.9500
# Epoch 134/200
# 2/2 - 0s - loss: 0.0430 - accuracy: 0.9514 - val_loss: 0.0233 - val_accuracy: 0.9875
# Epoch 135/200
# 2/2 - 0s - loss: 0.0423 - accuracy: 0.9542 - val_loss: 0.0445 - val_accuracy: 0.9500
# Epoch 136/200
# 2/2 - 0s - loss: 0.0425 - accuracy: 0.9542 - val_loss: 0.0240 - val_accuracy: 0.9750
# Epoch 137/200
# 2/2 - 0s - loss: 0.0433 - accuracy: 0.9556 - val_loss: 0.0515 - val_accuracy: 0.9250
# Epoch 138/200
# 2/2 - 0s - loss: 0.0452 - accuracy: 0.9542 - val_loss: 0.0212 - val_accuracy: 0.9875
# Epoch 139/200
# 2/2 - 0s - loss: 0.0451 - accuracy: 0.9514 - val_loss: 0.0328 - val_accuracy: 0.9625
# Epoch 140/200
# 2/2 - 0s - loss: 0.0447 - accuracy: 0.9514 - val_loss: 0.0203 - val_accuracy: 0.9875
# Epoch 141/200
# 2/2 - 0s - loss: 0.0465 - accuracy: 0.9514 - val_loss: 0.0264 - val_accuracy: 0.9750
# Epoch 142/200
# 2/2 - 0s - loss: 0.0453 - accuracy: 0.9472 - val_loss: 0.0216 - val_accuracy: 0.9875
# Epoch 143/200
# 2/2 - 0s - loss: 0.0427 - accuracy: 0.9556 - val_loss: 0.0201 - val_accuracy: 0.9875
# Epoch 144/200
# 2/2 - 0s - loss: 0.0420 - accuracy: 0.9569 - val_loss: 0.0950 - val_accuracy: 0.8750
# Epoch 145/200
# 2/2 - 0s - loss: 0.0509 - accuracy: 0.9431 - val_loss: 0.0231 - val_accuracy: 0.9750
# Epoch 146/200
# 2/2 - 0s - loss: 0.0518 - accuracy: 0.9333 - val_loss: 0.0699 - val_accuracy: 0.8875
# Epoch 147/200
# 2/2 - 0s - loss: 0.0460 - accuracy: 0.9500 - val_loss: 0.0208 - val_accuracy: 0.9875
# Epoch 148/200
# 2/2 - 0s - loss: 0.0430 - accuracy: 0.9542 - val_loss: 0.0240 - val_accuracy: 0.9750
# Epoch 149/200
# 2/2 - 0s - loss: 0.0404 - accuracy: 0.9556 - val_loss: 0.0627 - val_accuracy: 0.9000
# Epoch 150/200
# 2/2 - 0s - loss: 0.0444 - accuracy: 0.9514 - val_loss: 0.0192 - val_accuracy: 0.9875
# Epoch 151/200
# 2/2 - 0s - loss: 0.0436 - accuracy: 0.9556 - val_loss: 0.0532 - val_accuracy: 0.9250
# Epoch 152/200
# 2/2 - 0s - loss: 0.0431 - accuracy: 0.9542 - val_loss: 0.0277 - val_accuracy: 0.9750
# Epoch 153/200
# 2/2 - 0s - loss: 0.0403 - accuracy: 0.9569 - val_loss: 0.0201 - val_accuracy: 0.9875
# Epoch 154/200
# 2/2 - 0s - loss: 0.0403 - accuracy: 0.9583 - val_loss: 0.0591 - val_accuracy: 0.9125
# Epoch 155/200
# 2/2 - 0s - loss: 0.0428 - accuracy: 0.9542 - val_loss: 0.0205 - val_accuracy: 0.9875
# Epoch 156/200
# 2/2 - 0s - loss: 0.0408 - accuracy: 0.9569 - val_loss: 0.0292 - val_accuracy: 0.9625
# Epoch 157/200
# 2/2 - 0s - loss: 0.0393 - accuracy: 0.9583 - val_loss: 0.0391 - val_accuracy: 0.9500
# Epoch 158/200
# 2/2 - 0s - loss: 0.0410 - accuracy: 0.9542 - val_loss: 0.0233 - val_accuracy: 0.9750
# Epoch 159/200
# 2/2 - 0s - loss: 0.0393 - accuracy: 0.9583 - val_loss: 0.0347 - val_accuracy: 0.9500
# Epoch 160/200
# 2/2 - 0s - loss: 0.0395 - accuracy: 0.9569 - val_loss: 0.0254 - val_accuracy: 0.9750
# Epoch 161/200
# 2/2 - 0s - loss: 0.0391 - accuracy: 0.9556 - val_loss: 0.0250 - val_accuracy: 0.9750
# Epoch 162/200
# 2/2 - 0s - loss: 0.0387 - accuracy: 0.9583 - val_loss: 0.0277 - val_accuracy: 0.9625
# Epoch 163/200
# 2/2 - 0s - loss: 0.0386 - accuracy: 0.9597 - val_loss: 0.0269 - val_accuracy: 0.9625
# Epoch 164/200
# 2/2 - 0s - loss: 0.0384 - accuracy: 0.9597 - val_loss: 0.0263 - val_accuracy: 0.9750
# Epoch 165/200
# 2/2 - 0s - loss: 0.0385 - accuracy: 0.9611 - val_loss: 0.0274 - val_accuracy: 0.9625
# Epoch 166/200
# 2/2 - 0s - loss: 0.0397 - accuracy: 0.9597 - val_loss: 0.0515 - val_accuracy: 0.9250
# Epoch 167/200
# 2/2 - 0s - loss: 0.0408 - accuracy: 0.9556 - val_loss: 0.0173 - val_accuracy: 0.9875
# Epoch 168/200
# 2/2 - 0s - loss: 0.0414 - accuracy: 0.9542 - val_loss: 0.0450 - val_accuracy: 0.9375
# Epoch 169/200
# 2/2 - 0s - loss: 0.0398 - accuracy: 0.9569 - val_loss: 0.0188 - val_accuracy: 0.9875
# Epoch 170/200
# 2/2 - 0s - loss: 0.0402 - accuracy: 0.9583 - val_loss: 0.0366 - val_accuracy: 0.9500
# Epoch 171/200
# 2/2 - 0s - loss: 0.0392 - accuracy: 0.9583 - val_loss: 0.0204 - val_accuracy: 0.9750
# Epoch 172/200
# 2/2 - 0s - loss: 0.0399 - accuracy: 0.9569 - val_loss: 0.0349 - val_accuracy: 0.9625
# Epoch 173/200
# 2/2 - 0s - loss: 0.0384 - accuracy: 0.9597 - val_loss: 0.0405 - val_accuracy: 0.9375
# Epoch 174/200
# 2/2 - 0s - loss: 0.0374 - accuracy: 0.9639 - val_loss: 0.0161 - val_accuracy: 0.9875
# Epoch 175/200
# 2/2 - 0s - loss: 0.0404 - accuracy: 0.9569 - val_loss: 0.0638 - val_accuracy: 0.9125
# Epoch 176/200
# 2/2 - 0s - loss: 0.0408 - accuracy: 0.9542 - val_loss: 0.0162 - val_accuracy: 0.9875
# Epoch 177/200
# 2/2 - 0s - loss: 0.0401 - accuracy: 0.9583 - val_loss: 0.0532 - val_accuracy: 0.9250
# Epoch 178/200
# 2/2 - 0s - loss: 0.0390 - accuracy: 0.9597 - val_loss: 0.0174 - val_accuracy: 0.9875
# Epoch 179/200
# 2/2 - 0s - loss: 0.0384 - accuracy: 0.9597 - val_loss: 0.0614 - val_accuracy: 0.9125
# Epoch 180/200
# 2/2 - 0s - loss: 0.0416 - accuracy: 0.9569 - val_loss: 0.0153 - val_accuracy: 0.9875
# Epoch 181/200
# 2/2 - 0s - loss: 0.0403 - accuracy: 0.9583 - val_loss: 0.0772 - val_accuracy: 0.9000
# Epoch 182/200
# 2/2 - 0s - loss: 0.0454 - accuracy: 0.9458 - val_loss: 0.0152 - val_accuracy: 0.9875
# Epoch 183/200
# 2/2 - 0s - loss: 0.0425 - accuracy: 0.9542 - val_loss: 0.1229 - val_accuracy: 0.8250
# Epoch 184/200
# 2/2 - 0s - loss: 0.0565 - accuracy: 0.9264 - val_loss: 0.0151 - val_accuracy: 0.9875
# Epoch 185/200
# 2/2 - 0s - loss: 0.0381 - accuracy: 0.9583 - val_loss: 0.1080 - val_accuracy: 0.8625
# Epoch 186/200
# 2/2 - 0s - loss: 0.0509 - accuracy: 0.9333 - val_loss: 0.0196 - val_accuracy: 0.9750
# Epoch 187/200
# 2/2 - 0s - loss: 0.0512 - accuracy: 0.9361 - val_loss: 0.1243 - val_accuracy: 0.8375
# Epoch 188/200
# 2/2 - 0s - loss: 0.0586 - accuracy: 0.9250 - val_loss: 0.0195 - val_accuracy: 0.9750
# Epoch 189/200
# 2/2 - 0s - loss: 0.0520 - accuracy: 0.9347 - val_loss: 0.0927 - val_accuracy: 0.8750
# Epoch 190/200
# 2/2 - 0s - loss: 0.0474 - accuracy: 0.9458 - val_loss: 0.0152 - val_accuracy: 0.9875
# Epoch 191/200
# 2/2 - 0s - loss: 0.0425 - accuracy: 0.9556 - val_loss: 0.0251 - val_accuracy: 0.9750
# Epoch 192/200
# 2/2 - 0s - loss: 0.0383 - accuracy: 0.9583 - val_loss: 0.0390 - val_accuracy: 0.9500
# Epoch 193/200
# 2/2 - 0s - loss: 0.0378 - accuracy: 0.9597 - val_loss: 0.0190 - val_accuracy: 0.9875
# Epoch 194/200
# 2/2 - 0s - loss: 0.0374 - accuracy: 0.9611 - val_loss: 0.0344 - val_accuracy: 0.9500
# Epoch 195/200
# 2/2 - 0s - loss: 0.0375 - accuracy: 0.9583 - val_loss: 0.0178 - val_accuracy: 0.9875
# Epoch 196/200
# 2/2 - 0s - loss: 0.0377 - accuracy: 0.9597 - val_loss: 0.0194 - val_accuracy: 0.9875
# Epoch 197/200
# 2/2 - 0s - loss: 0.0360 - accuracy: 0.9611 - val_loss: 0.0642 - val_accuracy: 0.9000
# Epoch 198/200
# 2/2 - 0s - loss: 0.0388 - accuracy: 0.9583 - val_loss: 0.0146 - val_accuracy: 0.9875
# Epoch 199/200
# 2/2 - 0s - loss: 0.0414 - accuracy: 0.9569 - val_loss: 0.0705 - val_accuracy: 0.9000
# Epoch 200/200
# 2/2 - 0s - loss: 0.0418 - accuracy: 0.9569 - val_loss: 0.0151 - val_accuracy: 0.9875

# %% [markdown]
# ## Test the model

# %% [markdown]
# We are going to test the model with 20 % of the total videos. This videos have not been used to train the network.

# %%
result = model.evaluate(np.array(data_test), np.array(target_test))
# Out:
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0657 - accuracy: 0.9100

# %% [markdown]
# ## Print the model accuracy

# %%
for name, value in zip(model.metrics_names, result):
    print(name, value)
# Out:
# loss 0.06567281484603882
# accuracy 0.9100000262260437

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('destination_path.eps', format='eps', dpi=1000)
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.savefig('destination_path1.eps', format='eps', dpi=1000)
plt.show()
